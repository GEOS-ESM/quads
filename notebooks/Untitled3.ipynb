# %%
import sys
print(sys.executable)
# Out:
# /gpfsm/dulocal15/sles15/other/jupyter/lab/4.2.5/bin/python

# %%
import dask
import dask.array as da
print("dask:", dask.__version__)
print("dask.array ok:", da.__name__)
# Out:
# dask: 2024.10.0
# dask.array ok: dask.array
