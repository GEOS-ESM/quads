# %%
#import sys
#print(sys.executable)

#import sys
#!{sys.executable} -m conda install -y -c conda-forge dask distributed
#!{sys.executable} -m pip install dask distributed

# %%
# See how many violations are there for each data chunk identified by model, date, key_id
# there is another script for the analysis of a specific chunk of data

import pandas as pd
#import dask

root = "/home/sadhika8/JupyterLinks/nobackup/quads_results/geosfp/"
file = "quads_test_GEOSFP_2024_02_10_reference_date_2023-01.pkl"
path = root+file
df = pd.read_pickle(path)

# quick sanity checks
print(type(df))
print(df.shape)
print(df.columns)

# inspect contents
#print(df.tail())          # 5 rows
#print(df.tail())          # last 5 rows
print(df.info())          # dtypes + non-null counts
print(df.describe())      # numeric summary
# Out:
# <class 'pandas.core.frame.DataFrame'>
# (87695, 7)
# Index(['id_string', 'no_of_violations_left', 'no_of_violations_right',
#        'fence_low', 'fence_high', 'quantile_values', 'q_list'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87695 entries, 0 to 87694
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id_string               87695 non-null  object
#  1   no_of_violations_left   87695 non-null  int64
#  2   no_of_violations_right  87695 non-null  int64
#  3   fence_low               87695 non-null  float64
#  4   fence_high              87695 non-null  float64
#  5   quantile_values         87695 non-null  object
#  6   q_list                  87695 non-null  object
# dtypes: float64(2), int64(2), object(3)
# memory usage: 4.7+ MB
# None
#        no_of_violations_left  no_of_violations_right     fence_low  \
# count           87695.000000            8.769500e+04  8.769500e+04
# mean             3306.765380            4.024333e+03 -6.982386e+09
# std             49475.342719            5.285918e+04  9.789979e+10
# min                 0.000000            0.000000e+00 -3.513093e+12
# 25%                 0.000000            0.000000e+00 -1.706798e-04
# 50%                 0.000000            0.000000e+00 -1.783893e-12
# 75%                 0.000000            0.000000e+00  0.000000e+00
# max            930816.000000            2.239479e+06  2.114228e+08
#
#          fence_high
# count  8.769500e+04
# mean   7.109479e+09
# std    9.845833e+10
# min   -2.160971e+01
# 25%    9.494170e-13
# 50%    1.597498e-05
# 75%    7.124185e-01
# max    3.534588e+12

# %%
rows_with_nulls = df[df.isna().any(axis=1)]
print(rows_with_nulls.head())
# Out:
# Empty DataFrame
# Columns: [id_string, no_of_violations_left, no_of_violations_right, fence_low, fence_high, quantile_values, q_list]
# Index: []

# %%
df_sorted = df.sort_values("no_of_violations_left", ascending=False)
df_sorted.head()
# Out:
#                              id_string  no_of_violations_left  \
# 14617  inst3_3d_aer_Nv|MSA|19.0|Strat3                 930816
# 14520   inst3_3d_aer_Nv|MSA|7.0|Strat2                 930816
# 14569  inst3_3d_aer_Nv|MSA|13.0|Strat3                 930816
# 14517   inst3_3d_aer_Nv|MSA|6.0|Strat7                 930816
# 14620  inst3_3d_aer_Nv|MSA|19.0|Strat6                 930816
#
#        no_of_violations_right     fence_low    fence_high  \
# 14617                       0  1.787399e-11  1.819847e-11
# 14520                       0  1.810474e-11  1.826679e-11
# 14569                       0  1.781312e-11  1.826410e-11
# 14517                       0  1.809719e-11  1.828372e-11
# 14620                       0  1.766103e-11  1.833935e-11
#
#                                          quantile_values  \
# 14617  [1.792988719555577e-11, 1.793368657233502e-11,...
# 14520  [1.815121434041167e-11, 1.8154346391184243e-11...
# 14569  [1.7913580925821294e-11, 1.7919479979836405e-1...
# 14517  [1.8161729649612825e-11, 1.8167831014636223e-1...
# 14620  [1.7737295554098864e-11, 1.7742489711668967e-1...
#
#                                                   q_list
# 14617  [1e-07, 1e-06, 1e-05, 0.0001, 0.001, 0.01, 0.1...
# 14520  [1e-07, 1e-06, 1e-05, 0.0001, 0.001, 0.01, 0.1...
# 14569  [1e-07, 1e-06, 1e-05, 0.0001, 0.001, 0.01, 0.1...
# 14517  [1e-07, 1e-06, 1e-05, 0.0001, 0.001, 0.01, 0.1...
# 14620  [1e-07, 1e-06, 1e-05, 0.0001, 0.001, 0.01, 0.1...

# %%
row = df[df["id_string"] == "inst3_3d_aer_Nv|MSA|19.0|Strat3"].iloc[0]
fence_low, fence_high = row["fence_low"], row["fence_high"]

# %%
print(fence_low, fence_high)
# Out:
# 1.787398692112653e-11 1.8198466829520004e-11
