# %%
#import sys
#print(sys.executable)

#import sys
#!{sys.executable} -m conda install -y -c conda-forge dask distributed
#!{sys.executable} -m pip install dask distributed

# %%
# See how many violations are there for each data chunk identified by model, date, key_id
# there is another script for the analysis of a specific chunk of data

import pandas as pd
#import dask

root = "/home/sadhika8/JupyterLinks/nobackup/quads_results/GEOSFP/2024/02/01"
file = "quads_results_geosfp_2024_02_01_reference_date_2023-01.pkl"
path = "/home/sadhika8/JupyterLinks/nobackup/quads_results/GEOSFP/2024/02/01/quads_results_geosfp_2024_02_01_reference_date_2023-01.pkl" #root + file
df = pd.read_pickle(path)

# quick sanity checks
print(type(df))
print(df.shape)
print(df.columns)

# inspect contents
#print(df.tail())          # 5 rows
#print(df.tail())          # last 5 rows
print(df.info())          # dtypes + non-null counts
print(df.describe())      # numeric summary
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 10
#       8 file = "quads_results_geosfp_2024_02_01_reference_date_2023-01.pkl"
#       9 path = "/home/sadhika8/JupyterLinks/nobackup/quads_results/GEOSFP/2024/02/01/quads_results_geosfp_2024_02_01_reference_date_2023-01.pkl" #root + file
# ---> 10 df = pd.read_pickle(path)
#      12 # quick sanity checks
#      13 print(type(df))
#
# File ~/JupyterLinks/nobackup/.conda/envs/dataCompress/lib/python3.13/site-packages/pandas/io/pickle.py:185, in read_pickle(filepath_or_buffer, compression, storage_options)
#     123 """
#     124 Load pickled pandas object (or any object) from file.
#     125
#    (...)    182 4    4    9
#     183 """
#     184 excs_to_catch = (AttributeError, ImportError, ModuleNotFoundError, TypeError)
# --> 185 with get_handle(
#     186     filepath_or_buffer,
#     187     "rb",
#     188     compression=compression,
#     189     is_text=False,
#     190     storage_options=storage_options,
#     191 ) as handles:
#     192     # 1) try standard library Pickle
#     193     # 2) try pickle_compat (older pandas version) to handle subclass changes
#     194     # 3) try pickle_compat with latin-1 encoding upon a UnicodeDecodeError
#     196     try:
#     197         # TypeError for Cython complaints about object.__new__ vs Tick.__new__
#     198         try:
#
# File ~/JupyterLinks/nobackup/.conda/envs/dataCompress/lib/python3.13/site-packages/pandas/io/common.py:882, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#    (...)    878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
# --> 882         handle = open(handle, ioargs.mode)
#     883     handles.append(handle)
#     885 # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/sadhika8/JupyterLinks/nobackup/quads_results/GEOSFP/2024/02/01/quads_results_geosfp_2024_02_01_reference_date_2023-01.pkl'

# %%
rows_with_nulls = df[df.isna().any(axis=1)]
print(rows_with_nulls.head())

# %%
df_sorted = df.sort_values("no_of_violations_left", ascending=False)
df_sorted.head()

# %%
row = df[df["id_string"] == "inst3_3d_aer_Nv|MSA|19.0|Strat3"].iloc[0]
fence_low, fence_high = row["fence_low"], row["fence_high"]

# %%
print(fence_low, fence_high)
# Out:
# 1.787398692112653e-11 1.8198466829520004e-11

# %%
print(row["no_of_violations_left"])
# Out:
# 930816
